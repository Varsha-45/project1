# %%
import pandas as pd
import numpy as np
import warnings as w
w.filterwarnings("ignore")

# %%
ds = pd.read_csv(r"C:\Users\vkbal\OneDrive\Desktop\Campaign data.csv")
ds1= pd.read_csv(r"C:\Users\vkbal\OneDrive\Desktop\Campaign data2.csv")

# %%
ds
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       30-12-2019   Pinterest       Kicks campaign 2       Display
# 1       30-12-2019   Pinterest       Kicks campaign 2       Display
# 2       30-12-2019   Pinterest       Kicks campaign 2       Display
# 3       30-12-2019   Pinterest       Kicks campaign 2       Display
# 4       30-12-2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
ds1
# Out:
#                  Campaign   Message type        Model
# 0       Sentra campaign 2  Future Market       Sentra
# 1       Sentra campaign 4  Future Market       Sentra
# 2       Sentra campaign 3  Future Market       Sentra
# 3       Sentra campaign 1  Future Market       Sentra
# 4       Altima campaign 1  Future Market       Altima
# 5       Altima campaign 5  Future Market       Altima
# 6       Altima campaign 4  Future Market       Altima
# 7       Altima campaign 6  Future Market       Altima
# 8        Kicks campaign 6  Future Market        Kicks
# 9        Kicks campaign 5  Future Market        Kicks
# 10       Rogue campaign 1  Future Market        Rogue
# 11       Rogue campaign 3  Future Market        Rogue
# 12       Rogue pre launch  Future Market        Rogue
# 13       Rogue campaign 5  Future Market        Rogue
# 14       Rogue campaign 4  Future Market        Rogue
# 15  Pathfinder campaign 3    Near Market   Pathfinder
# ...

# %%
ds2 = pd.merge(ds, ds1)

# %%
ds2
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       30-12-2019   Pinterest       Kicks campaign 2       Display
# 1       30-12-2019   Pinterest       Kicks campaign 2       Display
# 2       30-12-2019   Pinterest       Kicks campaign 2       Display
# 3       30-12-2019   Pinterest       Kicks campaign 2       Display
# 4       30-12-2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# ...

# %%
ds2.dtypes
# Out:
# Date             object
# Data source      object
# Campaign         object
# Media Type       object
# City             object
# Metric           object
# Value           float64
# Message type     object
# Model            object
# dtype: object

# %%
ds2['Date'] = pd.to_datetime(ds2['Date'])

# %%
ds2.dtypes
# Out:
# Date            datetime64[ns]
# Data source             object
# Campaign                object
# Media Type              object
# City                    object
# Metric                  object
# Value                  float64
# Message type            object
# Model                   object
# dtype: object

# %%
ds2['Month']= ds2['Date'].dt.month

# %%
ds2
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
ds2[ds2['Metric'] == 'Impressions']
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.0  Near Market
# ...

# %%
ds2.dtypes
# Out:
# Date             object
# Data source      object
# Campaign         object
# Media Type       object
# City             object
# Metric           object
# Value           float64
# Message type     object
# Model            object
# dtype: object

# %%
ds2['Date'] = pd.to_datetime(ds2['Date'])

# %%
ds2
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
ds2.dtypes
# Out:
# Date            datetime64[ns]
# Data source             object
# Campaign                object
# Media Type              object
# City                    object
# Metric                  object
# Value                  float64
# Message type            object
# Model                   object
# dtype: object

# %%
ds2['Month'] = ds2['Date'].dt.month

# %%
ds2
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
ds2[ds2.duplicated()]
# Out:
#              Date Data source      Campaign Media Type  \
# 80807  2021-03-29   Pinterest  shop at home    Display
# 80858  2021-03-29   Pinterest  shop at home    Display
# 80907  2021-03-29   Pinterest  shop at home    Display
# 80908  2021-03-29   Pinterest  shop at home    Display
# 80909  2021-03-29   Pinterest  shop at home    Display
# ...           ...         ...           ...        ...
# 122584 2021-09-27   Pinterest  shop at home    Display
# 122585 2021-09-27   Pinterest  shop at home    Display
# 122586 2021-09-27   Pinterest  shop at home    Display
# 122587 2021-09-27   Pinterest  shop at home    Display
# 122588 2021-09-27   Pinterest  shop at home    Display
#
#                               City       Metric   Value   Message type  \
# 80807                        Utica       Clicks    3.00  Future Market
# 80858                        Utica       Clicks    3.00  Future Market
# 80907                        Utica  Impressions  750.00  Future Market
# ...

# %%
ds2['Metric']
# Out:
# 0         Impressions
# 1          Media Cost
# 2              Clicks
# 3         Impressions
# 4          Media Cost
#              ...
# 123694     Media Cost
# 123695         Clicks
# 123696    Impressions
# 123697     Media Cost
# 123698         Clicks
# Name: Metric, Length: 123699, dtype: object

# %%
ds2.drop_duplicates(inplace= True)

# %%
ds2.columns
# Out:
# Index(['Date', 'Data source', 'Campaign', 'Media Type', 'City', 'Metric',
#        'Value', 'Message type', 'Model', 'Month'],
#       dtype='object')

# %%
ds2.groupby('Model')['Month'].sum().sort_values(ascending = False)
# Out:
# Model
# Pathfinder     245601
# Altima         200898
# Rogue          157035
# Armada          98412
# Sentra          81213
# Kicks           52083
# Multi-Model     15344
# Name: Month, dtype: int32

# %%
ds2
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %% [markdown]
# 1

# %%
ds2[ds2['Metric'] == 'Impressions'].groupby('Metric')['Month'].head(5).sort_values(ascending = False)
# Out:
# 0     12
# 3     12
# 6     12
# 9     12
# 12    12
# Name: Month, dtype: int32

# %%
ds2.groupby('Metric')['Month'].sum().sort_values(ascending = True)
# Out:
# Metric
# Clicks         285240
# Impressions    285240
# Media Cost     285240
# Name: Month, dtype: int32

# %%
ds2['Campaign'].value_counts()
# Out:
# Campaign
# Armada campaign 2        13392
# Rogue campaign 4          6030
# Pathfinder campaign 2     5670
# Altima campaign 3         5484
# Armada campaign 4         5400
# Rogue campaign 2          4923
# Rogue campaign 5          4560
# Pathfinder campaign 7     4332
# Pathfinder campaign 8     4302
# Pathfinder campaign 6     4254
# Pathfinder campaign 5     4254
# Sentra campaign 3         4209
# Kicks campaign 4          4185
# Sentra campaign 1         3954
# Kicks campaign 3          3885
# Altima campaign 2         3840
# shop at home              3216
# Rogue campaign 1          3000
# Altima campaign 8         2991
# Armada campaign 3         2526
# Pathfinder campaign 1     2520
# Kicks campaign 6          2511
# Altima campaign 5         2508
# Altima campaign 1         2454
# Altima campaign 7         2436
# Kicks campaign 5          2118
# Rogue pre launch          1944
# Pathfinder campaign 4     1890
# Pathfinder campaign 3     1440
# ...

# %%
ds2['Metric'].value_counts()
# Out:
# Metric
# Impressions    41233
# Media Cost     41233
# Clicks         41233
# Name: count, dtype: int64

# %%
ds2['Media Type'].unique()
# Out:
# array(['Display', 'Online Video'], dtype=object)

# %%
cpm = ds2['Value'].sum()/41233 * 1000

# %%
cpm
# Out:
# 20919656.876045883

# %%
ds2.groupby(['Media Type', 'Month'])[['Value']].mean()
# Out:
#                            Value
# Media Type   Month
# Display      1          8.085271
#              2      18101.660471
#              3      16472.205729
#              4       2914.408085
#              5          6.551845
#              6          8.319527
#              7          6.040632
#              8          4.612903
#              9      11305.402966
#              10         8.846123
#              11         5.127946
#              12         6.459459
# Online Video 1       4921.104459
#              2       7744.503079
#              3       7370.839439
#              4       6907.717932
#              5         15.694530
#              6        283.990234
#              7       1055.305907
#              8       7707.028095
#              9       9012.731701
#              10      7949.702510
#              11      4985.346979
#              12      6989.815205

# %%
ds2['Media Type'].value_counts()
# Out:
# Media Type
# Online Video    99363
# Display         24336
# Name: count, dtype: int64

# %%
ds2.groupby('Media Type')[['Value']].sum()
# Out:
#                      Value
# Media Type
# Display       1.796768e+08
# Online Video  6.829034e+08

# %%
display = 1.796768/ 41233 * 1000

# %%
display
# Out:
# 0.043575970703077636

# %%
online_video = 6.829034 / 41233 * 1000

# %%
online_video
# Out:
# 0.16562059515436667

# %%
ddd= ds2[ds2['Metric']== 'Impressions'].groupby(['Campaign', 'Metric'])[['Message type']].sum().sort_values(by = 'Message type', ascending = False)

# %%
dd= ds2[ds2['Metric']== 'Clicks'].groupby(['Campaign', 'Metric'])[['Message type']].sum().sort_values(by = 'Message type', ascending = False)

# %%
dd
# Out:
#                                                                    Message type
# Campaign              Metric
# Armada campaign 2     Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 2 Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Armada campaign 4     Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 7 Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 8 Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 6 Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 5 Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Altima campaign 8     Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Armada campaign 3     Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 1 Clicks  Near MarketNear MarketNear MarketNear MarketNe...
# ...

# %%
dd.shape
# Out:
# (58, 1)

# %%
ddd
# Out:
#                                                                         Message type
# Campaign              Metric
# Armada campaign 2     Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 2 Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Armada campaign 4     Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 7 Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 8 Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 6 Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 5 Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Altima campaign 8     Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Armada campaign 3     Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# Pathfinder campaign 1 Impressions  Near MarketNear MarketNear MarketNear MarketNe...
# ...

# %%
ddd.shape
# Out:
# (58, 1)

# %%
ds2
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       30-12-2019   Pinterest       Kicks campaign 2       Display
# 1       30-12-2019   Pinterest       Kicks campaign 2       Display
# 2       30-12-2019   Pinterest       Kicks campaign 2       Display
# 3       30-12-2019   Pinterest       Kicks campaign 2       Display
# 4       30-12-2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# ...

# %%
ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122629 entries, 0 to 123698
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          122629 non-null  object
#  1   Data source   122629 non-null  object
#  2   Campaign      122629 non-null  object
#  3   Media Type    122629 non-null  object
#  4   City          122629 non-null  object
#  5   Metric        122629 non-null  object
#  6   Value         122629 non-null  float64
#  7   Message type  122629 non-null  object
#  8   Model         122629 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 9.4+ MB

# %%
ds2.isnull().sum()
# Out:
# Date            0
# Data source     0
# Campaign        0
# Media Type      0
# City            0
# Metric          0
# Value           0
# Message type    0
# Model           0
# dtype: int64

# %%
ds2['Day'] = ds2['Date'].dt.day

# %%
ds2['Year'] = ds2['Date'].dt.year

# %%
ds2
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
dss2 = (ds2[ds2['Metric']== 'Impressions'])

# %%
dss2
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.0  Near Market
# ...

# %%
dss2.groupby(['Month', 'Metric', 'Year'])[['Value']].sum().sort_values(by = 'Value', ascending = False).head(5)
# Out:
#                               Value
# Month Metric      Year
# 9     Impressions 2021  165961494.0
# 10    Impressions 2020  129386691.0
# 8     Impressions 2021  110579025.0
# 3     Impressions 2021  101719848.0
# 2     Impressions 2020   61351689.0

# %%
dss2.groupby(['Model', 'Metric'])[['Value']].sum().sort_values(by = 'Value' , ascending = False)
# Out:
#                                Value
# Model       Metric
# Pathfinder  Impressions  275832034.0
# Armada      Impressions  175569709.0
# Rogue       Impressions  132109157.0
# Altima      Impressions   99823376.0
# Kicks       Impressions   95929225.0
# Sentra      Impressions   64176011.0
# Multi-Model Impressions    4915930.0

# %%
ds2['Campaign']
# Out:
# 0              Kicks campaign 2
# 1              Kicks campaign 2
# 2              Kicks campaign 2
# 3              Kicks campaign 2
# 4              Kicks campaign 2
#                   ...
# 123694    Pathfinder campaign 7
# 123695    Pathfinder campaign 7
# 123696    Pathfinder campaign 7
# 123697    Pathfinder campaign 7
# 123698    Pathfinder campaign 7
# Name: Campaign, Length: 122629, dtype: object

# %%
dss2.groupby(['Message type', 'Campaign' , 'Metric' ])[['Value']].sum().sort_values(by = 'Message type' , ascending = False).head(3)
# Out:
#                                                       Value
# Message type Campaign              Metric
# Near Market  Pathfinder campaign 1 Impressions   48923126.0
#              Pathfinder campaign 2 Impressions  115286607.0
#              Pathfinder campaign 4 Impressions    5605811.0

# %%
dss2.groupby(['Campaign', 'Message type', 'Metric'])[['Value']].sum().sort_values(by = 'Value', ascending = False)
# Out:
#                                                        Value
# Campaign              Message type  Metric
# Armada campaign 2     Near Market   Impressions  118817195.0
# Pathfinder campaign 2 Near Market   Impressions  115286607.0
# Pathfinder campaign 6 Near Market   Impressions   51823574.0
# Pathfinder campaign 1 Near Market   Impressions   48923126.0
# Altima campaign 3     Future Market Impressions   45451489.0
# Armada campaign 4     Near Market   Impressions   37470993.0
# Altima campaign 1     Future Market Impressions   35863660.0
# Kicks campaign 4      Future Market Impressions   33664998.0
# Rogue campaign 5      Future Market Impressions   33448074.0
# Kicks campaign 6      Future Market Impressions   32993380.0
# Rogue campaign 4      Future Market Impressions   32510217.0
# Kicks campaign 3      Future Market Impressions   27167086.0
# Rogue campaign 2      Future Market Impressions   25647766.0
# Rogue campaign 1      Future Market Impressions   18925107.0
# ...

# %%
ds2.groupby(['Media Type', 'Month'])[['Value']].mean()
# Out:
#                            Value
# Media Type   Month
# Display      1          8.085271
#              2      18101.660471
#              3      17178.844665
#              4       2023.553793
#              5          6.983985
#              6          8.735784
#              7          6.300473
#              8          4.725375
#              9      11478.233773
#              10         8.846123
#              11         5.127946
#              12         6.459459
# Online Video 1       4921.104459
#              2       7744.503079
#              3       7370.839439
#              4       6907.717932
#              5         15.694530
#              6        283.990234
#              7       1055.305907
#              8       7707.028095
#              9       9012.731701
#              10      7949.702510
#              11      4985.346979
#              12      6989.815205

# %%
ds2['Campaign'].value_counts()
# Out:
# Campaign
# Armada campaign 2        13392
# Rogue campaign 4          6030
# Pathfinder campaign 2     5670
# Altima campaign 3         5484
# Armada campaign 4         5400
# Rogue campaign 2          4923
# Rogue campaign 5          4560
# Pathfinder campaign 7     4332
# Pathfinder campaign 8     4302
# Pathfinder campaign 6     4254
# Pathfinder campaign 5     4254
# Sentra campaign 3         4209
# Kicks campaign 4          4185
# Sentra campaign 1         3954
# Kicks campaign 3          3885
# Altima campaign 2         3840
# Rogue campaign 1          3000
# Altima campaign 8         2991
# Armada campaign 3         2526
# Pathfinder campaign 1     2520
# Kicks campaign 6          2511
# Altima campaign 5         2508
# Altima campaign 1         2454
# Altima campaign 7         2436
# shop at home              2146
# Kicks campaign 5          2118
# Rogue pre launch          1944
# Pathfinder campaign 4     1890
# Pathfinder campaign 3     1440
# ...

# %%
inf = ds2[ds2['Message type']=='Near Market']

# %%
inf
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       30-12-2019   Pinterest       Kicks campaign 2       Display
# 1       30-12-2019   Pinterest       Kicks campaign 2       Display
# 2       30-12-2019   Pinterest       Kicks campaign 2       Display
# 3       30-12-2019   Pinterest       Kicks campaign 2       Display
# 4       30-12-2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# ...

# %%
info = inf.groupby(['Campaign','Message type'])['Value'].sum().sort_values(ascending=False)[:3]

# %%
info
# Out:
# Campaign               Message type
# Armada campaign 2      Near Market     1.197572e+08
# Pathfinder campaign 2  Near Market     1.160629e+08
# Pathfinder campaign 6  Near Market     5.285515e+07
# Name: Value, dtype: float64

# %%
inf1 = ds2[ds2['Message type']=='Future Market']

# %%
# Out:
# Empty DataFrame
# Columns: [Date, Data source, Campaign, Media Type, City, Metric, Value, Message type, Model]
# Index: []

# %%
cli=ds2[ds2['Metric']=='Clicks']

# %%
cli
# Out:
#              Date Data source               Campaign    Media Type  \
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 5      2019-12-30   Pinterest       Kicks campaign 2       Display
# 8      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 11     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 14     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123686 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123689 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123692 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City  Metric  Value Message type  \
# 2               Colorado Springs-Pueblo  Clicks    0.0  Near Market
# ...

# %%
clicks = cli.groupby(['Campaign', 'Metric'])[['Value']].sum().sort_values(by = 'Value', ascending = True)

# %%
clicks
# Out:
#                                  Value
# Campaign              Metric
# Armada campaign 1     Clicks       0.0
# Kicks campaign 2      Clicks       7.0
# Kicks campaign 1      Clicks      25.0
# Sentra campaign 10    Clicks     411.0
# Sentra campaign 13    Clicks     498.0
# Sentra campaign 17    Clicks     514.0
# Sentra campaign 5     Clicks     521.0
# Altima campaign 7     Clicks     672.0
# Sentra campaign 8     Clicks     695.0
# Sentra campaign 24    Clicks     839.0
# Sentra campaign 16    Clicks     859.0
# Sentra campaign 25    Clicks     864.0
# Sentra campaign 23    Clicks     952.0
# Sentra campaign 19    Clicks     959.0
# Sentra campaign 9     Clicks    1026.0
# Sentra campaign 15    Clicks    1058.0
# Sentra campaign 18    Clicks    1089.0
# Sentra campaign 4     Clicks    1380.0
# Sentra campaign 6     Clicks    1412.0
# Sentra campaign 22    Clicks    1502.0
# Sentra campaign 21    Clicks    1523.0
# Sentra campaign 20    Clicks    1581.0
# ...

# %%
imp = dss2.groupby(['Campaign' , 'Metric'])[['Value']].sum().sort_values(by = 'Value', ascending = False)

# %%
imp.shape
# Out:
# (58, 1)

# %%
cli.shape
# Out:
# (41233, 10)

# %%
com = pd.merge(imp, cli, on = 'Campaign')

# %%
com
# Out:
#                 Campaign      Value_x       Date Data source Media Type  \
# 0      Armada campaign 2  118817195.0 2020-02-03   Pinterest    Display
# 1      Armada campaign 2  118817195.0 2020-02-03   Pinterest    Display
# 2      Armada campaign 2  118817195.0 2020-02-03   Pinterest    Display
# 3      Armada campaign 2  118817195.0 2020-02-03   Pinterest    Display
# 4      Armada campaign 2  118817195.0 2020-02-03   Pinterest    Display
# ...                  ...          ...        ...         ...        ...
# 41228   Kicks campaign 2       1485.0 2021-02-08   Pinterest    Display
# 41229   Kicks campaign 2       1485.0 2021-02-08   Pinterest    Display
# 41230   Kicks campaign 2       1485.0 2021-02-15   Pinterest    Display
# 41231   Kicks campaign 2       1485.0 2021-02-15   Pinterest    Display
# 41232   Kicks campaign 2       1485.0 2021-02-22   Pinterest    Display
#
#                              City  Metric  Value_y Message type   Model  Month
# ...

# %%
mco = ds2[ds2['Metric'] =='Media Cost']

# %%
mco
# Out:
#              Date Data source               Campaign    Media Type  \
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# 7      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 10     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 13     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123685 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123688 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123691 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City      Metric   Value Message type  \
# 1               Colorado Springs-Pueblo  Media Cost    0.00  Near Market
# ...

# %%
total =mco['Metric'].value_counts()

# %%
total
# Out:
# Metric
# Media Cost    41233
# Name: count, dtype: int64

# %%
ddsy = dss2.groupby(['Campaign', 'Metric'])[['Value']].sum().sort_values(by = 'Value', ascending = True)

# %%
ddsy
# Out:
#                                          Value
# Campaign              Metric
# Kicks campaign 2      Impressions       1485.0
# Kicks campaign 1      Impressions     120791.0
# Sentra campaign 2     Impressions     193569.0
# Sentra campaign 4     Impressions     196841.0
# Altima campaign 4     Impressions     380995.0
# Sentra campaign 10    Impressions     859107.0
# Sentra campaign 13    Impressions     922310.0
# Sentra campaign 17    Impressions    1053431.0
# Sentra campaign 5     Impressions    1137379.0
# Altima campaign 5     Impressions    1176593.0
# Sentra campaign 8     Impressions    1356458.0
# Altima campaign 6     Impressions    1533773.0
# Sentra campaign 24    Impressions    1555632.0
# Sentra campaign 16    Impressions    1619686.0
# Sentra campaign 25    Impressions    1704259.0
# Armada campaign 1     Impressions    1799471.0
# Sentra campaign 23    Impressions    1870596.0
# Kicks campaign 5      Impressions    1981485.0
# ...

# %%
mer = pd.merge(ddsy, com, on = 'Campaign')

# %%
mer
# Out:
#                 Campaign        Value      Value_x       Date Data source  \
# 0       Kicks campaign 2       1485.0       1485.0 2019-12-30   Pinterest
# 1       Kicks campaign 2       1485.0       1485.0 2019-12-30   Pinterest
# 2       Kicks campaign 2       1485.0       1485.0 2020-01-06   Pinterest
# 3       Kicks campaign 2       1485.0       1485.0 2020-01-06   Pinterest
# 4       Kicks campaign 2       1485.0       1485.0 2020-01-06   Pinterest
# ...                  ...          ...          ...        ...         ...
# 41228  Armada campaign 2  118817195.0  118817195.0 2021-09-27   Pinterest
# 41229  Armada campaign 2  118817195.0  118817195.0 2021-09-27   Pinterest
# 41230  Armada campaign 2  118817195.0  118817195.0 2021-09-27   Pinterest
# 41231  Armada campaign 2  118817195.0  118817195.0 2021-09-27   Pinterest
# 41232  Armada campaign 2  118817195.0  118817195.0 2021-09-27   Pinterest
#
#       Media Type                        City  Metric  Value_y Message type  \
# ...
